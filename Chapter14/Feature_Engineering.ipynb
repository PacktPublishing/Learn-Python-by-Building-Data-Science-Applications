# %%
import pandas as pd
import numpy as np

# %matplotlib inline
import pylab as plt
plt.style.use('fivethirtyeight')

# %%
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
from io import StringIO
from IPython.display import Image  
import pydotplus

from sklearn.model_selection import cross_validate, cross_val_score

# %%
data = pd.read_csv('./data/EF_battles_corrected.csv', parse_dates=['start', 'end'])

# %%
data['result_num'] = data['result'].map({'axis':-1, 'allies':1}).fillna(0) # * data['result_prop']

# %%
mask = data[['allies_infantry', 'axis_infantry']].isnull().any(1)

# %%
data=data[~mask]

# %%
cols_to_fill = ['allies_planes', 'axis_planes', 'axis_tanks', 'allies_tanks', 'axis_guns', 'allies_guns']
mask_null = data[cols_to_fill].isnull()
data[cols_to_fill] = data[cols_to_fill].fillna(0)

# %%
data['end_num'] = (data['end'].dt.year -1938) * 12 +  data['end'].dt.month
data['start_num'] = (data['start'].dt.year -1938) * 12 +  data['start'].dt.month
data['duration'] = (data['end_num'] - data['start_num']).clip(lower=1)

# %%
cols = [
    'allies_infantry', 'axis_infantry', 'allies_tanks', 'axis_tanks', 
    'allies_planes', 'axis_planes', 'duration'
]

# %% [markdown]
# ## Models

# %%
model1 = DecisionTreeClassifier(random_state=2019, max_depth=10)

# %%
data[cols]
# Out:
#      allies_infantry  axis_infantry  allies_tanks  axis_tanks  allies_planes  \
# 0              240.0         3400.0           0.0         0.0            0.0
# 4            50000.0         5000.0          58.0       498.0            0.0
# 6              720.0        42200.0           0.0       350.0            0.0
# 8             2800.0        38000.0           0.0         0.0            0.0
# 9           225000.0       425000.0           0.0       500.0            0.0
# 10          124000.0       175000.0           0.0         0.0            0.0
# 11            8800.0       175000.0           0.0       200.0            0.0
# 12           70000.0        45000.0         400.0       800.0            0.0
# 13           22500.0        20000.0           0.0         0.0            0.0
# 14           18000.0        30000.0           0.0       400.0            0.0
# 15            6500.0        20000.0           0.0       200.0            0.0
# 17            4000.0        15000.0           0.0         0.0            0.0
# 18            2000.0         1200.0           0.0        70.0            0.0
# 19           55000.0        11500.0         100.0         0.0            0.0
# 20          300000.0        15000.0           0.0         0.0            0.0
# 21           25000.0        10000.0           0.0         0.0            0.0
# 22           60000.0        15000.0         100.0         0.0            0.0
# 23           30000.0          750.0         800.0         0.0            0.0
# 24            9000.0        17000.0           3.0       800.0            0.0
# 25          671165.0       750000.0        4522.0      1936.0            0.0
# 27          498000.0       655000.0        1393.0      1389.0         1210.0
# 30          650000.0       917000.0           0.0         0.0            0.0
# 32           45000.0        27500.0           0.0         0.0            0.0
# 33           78500.0        45000.0         200.0        72.0            0.0
# 34          581600.0       430000.0        1545.0      1780.0            0.0
# 35          300000.0       400000.0         317.0       600.0            0.0
# 36           34500.0       340223.0           0.0         0.0            0.0
# 37          627000.0       500000.0           0.0         0.0            0.0
# 41          190000.0       300000.0           0.0         0.0            0.0
# 125          0.0         1
# 126          0.0         1
# 128          0.0         1
# 129          0.0         1
# 130          0.0         1
# 131          0.0         1
# 132          0.0         1
#
# [84 rows x 7 columns]

# %%
cv = cross_validate(model1,
                    data[cols], 
                    data['result_num'],
                    cv=4)

cv = pd.DataFrame(cv)
print(cv.to_string())
# Out:
#    fit_time  score_time  test_score
# 0  0.013465    0.002273    0.500000
# 1  0.002305    0.000975    0.571429
# 2  0.002679    0.000995    0.428571
# 3  0.003222    0.001009    0.250000

# %%
cv['test_score'].mean()
# Out:
# 0.4375

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# #### Army size comparison

# %%
data['infantry_ratio'] = data['allies_infantry'] / data['axis_infantry']
cols.append('infantry_ratio')

for tp in 'infantry', 'planes', 'tanks', 'guns':
    data[f'{tp}_diff'] = data[f'allies_{tp}'] - data[f'axis_{tp}']
    cols.append(f'{tp}_diff')

# %%
scores = cross_val_score(model1, 
                         data[cols], 
                         data['result_num'],
                         cv=4)
pd.np.mean(scores)
# Out:
# 0.5141774891774892

# %%
scores
# Out:
# array([0.40909091, 0.52380952, 0.52380952, 0.6       ])

# %% [markdown]
# # leaders

# %%
from collections import Counter
# lea

# %%
alead = data['axis_leaders'].str.split(',')

# %%
# alead[alead.notnull()].apply(lambda x: 'Erich von Manstein' in x)

# %%
def _generate_binary_most_common(col, N=10):
    mask = col.notnull()
    lead_list = [ el.strip() for _, cell in col[mask].iteritems() for el in cell if el != '']
    c = Counter(lead_list)
    
    mc = c.most_common(N)
    df = pd.DataFrame(index=col.index, columns=[name[0] for name in mc])
    
    for name in df.columns:
        df.loc[mask, name] = col[mask].apply(lambda x: name in x).astype(int)
    return df.fillna(0)

# %%
axis_pop = _generate_binary_most_common(data['axis_leaders'].str.split(','), N=2)
allies_pop = _generate_binary_most_common(data['allies_leaders'].str.split(','), N=2)

# %%
data2 = pd.concat([data, axis_pop, allies_pop], axis=1)

# %%
cols2 = cols + axis_pop.columns.tolist() + allies_pop.columns.tolist()

# %%
model2 = DecisionTreeClassifier(random_state=2019, max_depth=15)

# %%
scores = cross_val_score(model1, 
                         data2[cols2], 
                         data2['result_num'],
                         cv=4)
pd.np.mean(scores)
# Out:
# 0.5369047619047619

# %% [markdown]
# ### Belligerents

# %%
data2['belligerents.allies']
# Out:
# 0                                                 Poland
# 4                                                 Poland
# 6                                                 Poland
# 8                                                 Poland
# 9                                                 Poland
# 10                                       Polish Republic
# 11                                                Poland
# 12                                                Poland
# 13                                                Poland
# 14                                                Poland
# 15                                          Soviet Union
# 17                                          Soviet Union
# 18                                          Soviet Union
# 19                                               Finland
# 20                                               Finland
# 21                                               Finland
# 22                                               Finland
# 23                                               Finland
# 24                                          Soviet Union
# 25                                          Soviet Union
# 27                                          Soviet Union
# 30          Soviet Union \n \n   United Kingdom [Note 2]
# 32                                          Soviet Union
# 33                                          Soviet Union
# 34                                          Soviet Union
# 35                                          Soviet Union
# 36                                          Soviet Union
# 37                                          Soviet Union
# 41                                          Soviet Union
# 42                                          Soviet Union
#                              ...
# 76                                          Soviet Union
# 77                                          Soviet Union
# 78                                          Soviet Union
# 79                                                   NaN
# 80                                          Soviet Union
# 84                                          Soviet Union
# 91                                          Soviet Union
# 96                                          Soviet Union
# 98     Soviet Union   Poland \n \n \n   Armia Krajowa...
# 100    Polish Underground State     Polish First Army...
# 101                              Soviet Union     Poland
# 103                                         Soviet Union
# 105    1st Czechoslovak Army in Slovakia \n \n   Slov...
# 106                        Soviet Union   Czechoslovakia
# 108                                         Soviet Union
# 111    Allies :    Soviet Union   Yugoslav Partisans ...
# 112                               Soviet Union   Romania
# 116                                Soviet Union   Poland
# 118                                         Soviet Union
# 119                  2nd Belorussian Front, Soviet Union
# 120                                         Soviet Union
# 123                                Soviet Union   Poland
# 124             Bulgaria       Soviet Union   Yugoslavia
# 125         Bulgaria   Soviet Union   Yugoslav Partisans
# 126      Soviet Union   Bulgaria     Austrian Resistance
# 128                                Soviet Union   Poland
# 129                                         Soviet Union
# 130                                Soviet Union   Poland
# 131    Allies :   Soviet Union   Czechoslovakia   Rom...
# 132                                   Yugoslav Partisans
# Name: belligerents.allies, Length: 84, dtype: object

# %%
scores = cross_val_score(model1, 
                         data2[cols2], 
                         data2['result_num'],
                         cv=4)
pd.np.mean(scores)
# Out:
# 0.5369047619047619

# %% [markdown]
# ## Hyper-parameter optimisation

# %%
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint as sp_randint

# %%
# specify parameters and distributions to sample from
param_dist = {"max_depth": sp_randint(5, 20),
              "max_features": sp_randint(1, len(cols2)),
              "min_samples_split": sp_randint(2, 11),
              "criterion": ["gini", "entropy"]}

# %%
rs = RandomizedSearchCV(
    model1,
    param_distributions=param_dist,
    cv=4, iid=False,
    random_state=2019,
    n_iter=50
)

# %%
rs.fit(data2[cols2], data2['result_num'])
# Out:
# RandomizedSearchCV(cv=4, error_score='raise-deprecating',
#                    estimator=DecisionTreeClassifier(class_weight=None,
#                                                     criterion='gini',
#                                                     max_depth=10,
#                                                     max_features=None,
#                                                     max_leaf_nodes=None,
#                                                     min_impurity_decrease=0.0,
#                                                     min_impurity_split=None,
#                                                     min_samples_leaf=1,
#                                                     min_samples_split=2,
#                                                     min_weight_fraction_leaf=0.0,
#                                                     presort=False,
#                                                     random_state=2019,
#                                                     splitter='best'),
#                    iid=Fals...
#                    param_distributions={'criterion': ['gini', 'entropy'],
#                                         'max_depth': <scipy.stats._distn_infrastructure.rv_frozen object at 0x1a1c29a828>,
#                                         'max_features': <scipy.stats._distn_infrastructure.rv_frozen object at 0x1a1c2960b8>,
#                                         'min_samples_split': <scipy.stats._distn_infrastructure.rv_frozen object at 0x1a1c260208>},
#                    pre_dispatch='2*n_jobs', random_state=2019, refit=True,
#                    return_train_score=False, scoring=None, verbose=0)

# %%
rs.best_score_
# Out:
# 0.5613636363636363

# %%
rs.best_estimator_
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=5,
#                        max_features=3, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=8,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=2019, splitter='best')

# %%
scores = cross_val_score(rs.best_estimator_, 
                         data2[cols2], 
                         data2['result_num'],
                         cv=4)
pd.np.mean(scores)
# Out:
# 0.5613636363636363

# %% [markdown]
# # Visualize the graph

# %%
dot_data = StringIO()

export_graphviz(rs.best_estimator_, out_file=dot_data,  
                filled=True, rounded=True,
                special_characters=True, feature_names=cols2)

graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
Image(graph.create_png())
