# %% [markdown]
# # Assigning variables

# %%
print('Hello World')
# Out:
# Hello World

# %%
pi = 3.14159265359    # decimal
name = 'Philipp'      # text
age = 31              # integer
sky_is_blue = True    # boolean

# %%
print(pi)
# Out:
# 3.14159265359

# %% [markdown]
# ## Packing multiple assignments on one line

# %%
x, y = 10, 5
print(x)
# Out:
# 10

# %%
print(y)
# Out:
# 5

# %% [markdown]
# ## Re-assigning (Updating the variable)

# %%
pi = 'Philipp'
print(pi)
# Out:
# Philipp

# %%
x, y = y, x

# %%
x
# Out:
# 5

# %% [markdown]
# ## Using non-defined variables will raise a NameError

# %%
print(non_existent_variable)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-8eb993205162> in <module>
# ----> 1 print(non_existent_variable)
#
# NameError: name 'non_existent_variable' is not defined

# %% [markdown]
# ## Tips - other ways to define value

# %%
ten_millions = 10_000_000
ten_millions
# Out:
# 10000000

# %%
small = .25
small
# Out:
# 0.25

# %%
sci_thousand = 10e2
sci_thousand
# Out:
# 1000.0

# %% [markdown]
# # Naming the variable

# %% [markdown]
# 1. No keywords and operator symbols (class, def, for, ..., +, -, @, etc)
# 2. No whitespace
# 2. Cannot start with number

# %%
counter = 0
pricey_car = 'Mercedes'
income = 120_000

# %%
class = 'Mercedes'
# Out:
#   File "<ipython-input-14-2daee69c2fcb>", line 1
#     class = 'Mercedes'
#           ^
# SyntaxError: invalid syntax

# %%
pricey@@car
# Out:
#   File "<ipython-input-15-ffd8cc768d68>", line 1
#     pricey@@car
#            ^
# SyntaxError: invalid syntax

# %%
1y_income = 120_000
# Out:
#   File "<ipython-input-16-2b923f9c6b91>", line 1
#     1y_income = 120_000
#             ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Data types

# %%
pi = 3.14159265359    # reassing it back
type(pi)
# Out:
# float

# %%
type(name)
# Out:
# str

# %%
type(age)
# Out:
# int

# %%
type(sky_is_blue)
# Out:
# bool

# %% [markdown]
# ## Floats and Integers

# %%
A = 6
B = 5

# %%
A + B
# Out:
# 11

# %%
A - B
# Out:
# 1

# %%
A / B
# Out:
# 1.2

# %%
A * B
# Out:
# 30

# %% [markdown]
# **Exponent**

# %%
2**3
# Out:
# 8

# %%
3**2
# Out:
# 9

# %% [markdown]
# **Integer division**

# %%
10 / 2
# Out:
# 5.0

# %%
9 // 4  # way faster
# Out:
# 2

# %%
10.0 // 4
2.0
# Out:
# 2.0

# %% [markdown]
# **Remainder**

# %%
10 % 3
# Out:
# 1

# %% [markdown]
# ## Self-assignment

# %%
count = 0

# %%
count +=1
count
# Out:
# 1

# %%
count -=1
count
# Out:
# 0

# %%
count +=1
count *=2
count
# Out:
# 2

# %%
count **= 2
count
# Out:
# 4

# %%
count /=2
count
# Out:
# 2.0

# %%
count //= 2
count
# Out:
# 1.0

# %%
10.0 // 4
# Out:
# 2.0

# %% [markdown]
# ## Order of operations

# %%
(2 + 10) / 2
# Out:
# 6.0

# %%
10 / (1 + 1)
# Out:
# 5.0

# %% [markdown]
# # Strings

# %%
text1 = 'This is a so-called “speakeasy”'

# %%
text2 = "This is Sam’s Tavern"

# %%
text3 = ''' This is Sam’s Tavern.
"Welcome everyone!" - is written on the door.
'''

# %%
print('Hello\nWorld!')
# Out:
# Hello
# World!

# %% [markdown]
# ## Operators

# %%
'Hello ' + 'World'
# Out:
# 'Hello World'

# %%
'Hello' * 3
# Out:
# 'HelloHelloHello'

# %% [markdown]
# ## Methods

# %%
'Hello World'.upper()
# Out:
# 'HELLO WORLD'

# %%
'Hello World'.lower()
# Out:
# 'hello world'

# %%
'hello world'.title()
# Out:
# 'Hello World'

# %%
'Hello world'.replace('world', 'planet')
# Out:
# 'Hello planet'

# %% [markdown]
# ## Formatting

# %%
'hello'.rjust(10, ' ')
# Out:
# '     hello'

# %%
'hello'.ljust(10, ' ')
# Out:
# 'hello     '

# %%
'999'.zfill(10)
# Out:
# '0000000999'

# %% [markdown]
# **Format method**

# %%
'Hello {} world and our blue {}'.format('beautiful','planet')
# Out:
# 'Hello beautiful world and our blue planet'

# %%
'{0} {2} {1} and our {2} {3}!'.format('Hello','World','Beautiful', 'Planet')
# Out:
# 'Hello Beautiful World and our Beautiful Planet!'

# %%
'Hello {adj} world!'.format(adj='beautiful')
# Out:
# 'Hello beautiful world!'

# %% [markdown]
# **F-strings**

# %%
adj = 'beautiful'
f'Hello {adj} world!'
# Out:
# 'Hello beautiful world!'

# %%
name = 'pHILIPP'
f'Hello, mr. {name.title()}'
# Out:
# 'Hello, mr. Philipp'

# %% [markdown]
# **Legacy formatting (do not use)**

# %%
name = 'David'
print('Hello, mr. %s' % name)
# Out:
# Hello, mr. David

# %% [markdown]
# **Formatting mini-language**

# %%
pct = .345
value = 45500
f'Price grew by {pct:.1%} or {value:,}'
# Out:
# 'Price grew by 34.5% or 45,500'

# %% [markdown]
# [Formatting mini-language link](https://docs.python.org/3/library/string.html#formatspec)

# %% [markdown]
# ## String as iterable

# %%
"Hello World"[0]
# Out:
# 'H'

# %%
"Hello World"[0:5]
# Out:
# 'Hello'

# %%
"World" in "Hello World!"
# Out:
# True

# %%
"Planet" in "Hello World!"
# Out:
# False

# %% [markdown]
# # Boolean

# %%
'World' == 'World'
# Out:
# True

# %%
pi == pi
# Out:
# True

# %%
"World" in "Hello World!"
# Out:
# True

# %%
pi != pi
# Out:
# False

# %% [markdown]
# ## Logical operators

# %%
not (5 > 4)
# Out:
# False

# %%
(5 > 4) | (6 < 5)
# Out:
# True

# %%
(5 > 4) & (6 < 5)
# Out:
# False

# %%
(5 > 4) ^ (5 < 6)
# Out:
# False

# %% [markdown]
# # Conversion

# %%
float("2.5")
# Out:
# 2.5

# %%
int("45")
# Out:
# 45

# %%
int(4.521)
# Out:
# 4

# %%
float(5)
# Out:
# 5.0

# %%
int(True)
# Out:
# 1

# %%
float(False)
# Out:
# 0.0

# %%
str(True)
# Out:
# 'True'

# %%
bool(0)
# Out:
# False

# %%
bool('Hello')
# Out:
# True

# %%
bool(115.5)
# Out:
# True

# %% [markdown]
# **Can't convert**

# %%
int("2.5")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-87-91a97d16ed7b> in <module>
# ----> 1 int("2.5")
#
# ValueError: invalid literal for int() with base 10: '2.5'

# %%
int("Hello")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-88-5cdea6865089> in <module>
# ----> 1 int("Hello")
#
# ValueError: invalid literal for int() with base 10: 'Hello'

# %% [markdown]
# # Practice

# %%
CONST = 32
RATIO = 5/9

T_f = 100

# %%
T_c = (T_f - CONST) * RATIO
T_c
# Out:
# 37.77777777777778

# %%
T_f2 = (T_c / RATIO) + CONST
T_f2
# Out:
# 100.0

# %%
T_f = 70
T_c = (T_f - CONST) * RATIO
T_c
# Out:
# 21.11111111111111
