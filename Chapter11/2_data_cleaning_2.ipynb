# %%
# %matplotlib inline
import pylab as plt
plt.style.use('fivethirtyeight')

import pandas as pd
import json

# %%
data = pd.read_csv('./data/Eastern Front.csv')

# %%
data.shape
# Out:
# (186, 23)

# %%
data.dtypes
# Out:
# Belligerents.allies                   object
# Belligerents.axis                     object
# Belligerents.third party              object
# Casualties and losses.allies          object
# Casualties and losses.axis            object
# Casualties and losses.third party     object
# Casualties and losses.total           object
# Commanders and leaders.allies         object
# Commanders and leaders.axis           object
# Commanders and leaders.third party    object
# Date                                  object
# Location                              object
# Result                                object
# Strength.allies                       object
# Strength.axis                         object
# Strength.third party                  object
# Strength.total                        object
# Territorial                           object
# level                                  int64
# name                                  object
# time                                  object
# ...

# %%
op = data[data.level == 1]

# %%
op.shape
# Out:
# (25, 23)

# %%
columns = ['Location', 'name', 'Date', 'Result', 'Belligerents.allies', 'Belligerents.axis']

# %%
op[columns]
# Out:
#                                               Location  \
# 15   Poland, eastern Germany, and the Free City of ...
# 20                                              Poland
# 26                                     Eastern Finland
# 60              Central, Northeast, and Eastern Europe
# 66                                                 NaN
# 73   Voronezh, Rostov to Stalingrad, Kuban, Caucasu...
# 78              Northern Caucasus and the Donets Basin
# 82   Southern shore of Lake Ladoga , near present-d...
# 89     Kursk, Kursk Oblast, Russian SFSR, Soviet Union
# 91                       Smolensk region, Soviet Union
# 93         Kharkov region, Ukrainian SSR, Soviet Union
# 95                         Dnieper River, Soviet Union
# 101                        South-western Ukrainian SSR
# 112  Narva, Estonia59°23′N 28°12′E﻿ / ﻿59.383°N 28....
# 114                 Crimea, Russian SFSR, Soviet Union
# 129  Soviet Union (present day Belarus, Baltic stat...
# ...
